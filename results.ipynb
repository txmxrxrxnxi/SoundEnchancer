# %% [markdown]
# Імпортування бібліотек

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Завантаження даних

# %%
df = pd.read_csv("comparison_results.csv")
df
# Out:
#       File  Centroid Diff Wiener  Mean Diff Wiener  Centroid Diff Lib Wiener  \
# 0    0.wav             41.949869         91.138655                  4.979133
# 1    1.wav             49.543342         92.308974                  4.057882
# 2   10.wav             57.250282         93.507695                  5.849571
# 3   11.wav             61.649904         95.211685                  5.384762
# 4   12.wav             45.256589         90.525073                  4.108429
# ..     ...                   ...               ...                       ...
# 95  95.wav             34.391208         75.747102                 10.340959
# 96  96.wav             36.036893         86.082381                  4.626439
# 97  97.wav             24.286233         57.429981                  5.460295
# 98  98.wav             15.553960         44.519880                  5.975255
# 99  99.wav             29.225611         79.235822                  3.858436
#
#     Mean Diff Lib Wiener
# 0              21.135186
# 1               2.585073
# 2               1.061451
# 3               0.690676
# 4               0.675105
# ..                   ...
# 95              0.273192
# 96              0.687553
# 97              0.206500
# 98              0.439847
# 99              0.265241
#
# [100 rows x 5 columns]

# %%
df.describe()
# Out:
#        Centroid Diff Wiener  Mean Diff Wiener  Centroid Diff Lib Wiener  \
# count            100.000000        100.000000                100.000000
# mean              37.830475         78.166118                  6.703393
# std               15.826102         18.656549                  2.877987
# min                8.462303         29.986542                  2.689603
# 25%               23.932667         67.827106                  5.015489
# 50%               38.242941         84.395486                  5.900486
# 75%               49.727151         92.727657                  7.934982
# max               67.521595         97.328496                 24.431696
#
#        Mean Diff Lib Wiener
# count            100.000000
# mean               1.406446
# std                2.762550
# min                0.000075
# 25%                0.210908
# 50%                0.487840
# 75%                1.405951
# max               21.135186

# %%
plt.figure(figsize=(10, 6))
for column in df.columns[1:]:
    plt.plot(df["File"], df[column], marker="o", label=column)
plt.xlabel("Файл")
plt.ylabel("Значення")
plt.title("Порівняння із зашумленими звуковими доріжками")
plt.legend()
plt.show()

# %%
df_clear = pd.read_csv("comparison_results.csv")
df_clear
# Out:
#       File  Centroid Diff Wiener  Mean Diff Wiener  Centroid Diff Lib Wiener  \
# 0    0.wav             41.949869         91.138655                  4.979133
# 1    1.wav             49.543342         92.308974                  4.057882
# 2   10.wav             57.250282         93.507695                  5.849571
# 3   11.wav             61.649904         95.211685                  5.384762
# 4   12.wav             45.256589         90.525073                  4.108429
# ..     ...                   ...               ...                       ...
# 95  95.wav             34.391208         75.747102                 10.340959
# 96  96.wav             36.036893         86.082381                  4.626439
# 97  97.wav             24.286233         57.429981                  5.460295
# 98  98.wav             15.553960         44.519880                  5.975255
# 99  99.wav             29.225611         79.235822                  3.858436
#
#     Mean Diff Lib Wiener
# 0              21.135186
# 1               2.585073
# 2               1.061451
# 3               0.690676
# 4               0.675105
# ..                   ...
# 95              0.273192
# 96              0.687553
# 97              0.206500
# 98              0.439847
# 99              0.265241
#
# [100 rows x 5 columns]

# %%
df_clear.describe()
# Out:
#        Centroid Diff Wiener  Mean Diff Wiener  Centroid Diff Lib Wiener  \
# count            100.000000        100.000000                100.000000
# mean              37.830475         78.166118                  6.703393
# std               15.826102         18.656549                  2.877987
# min                8.462303         29.986542                  2.689603
# 25%               23.932667         67.827106                  5.015489
# 50%               38.242941         84.395486                  5.900486
# 75%               49.727151         92.727657                  7.934982
# max               67.521595         97.328496                 24.431696
#
#        Mean Diff Lib Wiener
# count            100.000000
# mean               1.406446
# std                2.762550
# min                0.000075
# 25%                0.210908
# 50%                0.487840
# 75%                1.405951
# max               21.135186

# %%
plt.figure(figsize=(10, 6))
for column in df_clear.columns[1:]:
    plt.plot(df_clear["File"], df_clear[column], marker="o", label=column)
plt.xlabel("Файл")
plt.ylabel("Значення")
plt.title("Порівняння з чистими звуковими доріжками")
plt.legend()
plt.show()

# %%
df_absolute = pd.read_csv("absolute_results.csv")
df_absolute
# Out:
#       File  Clear Centroid  Clear Mean  Wiener Centroid  Wiener Mean  \
# 0    0.wav      603.425975    0.000006       827.584228     0.000244
# 1    1.wav      597.759291    0.000017       993.296134     0.000497
# 2   10.wav      862.262466    0.018876      1339.823230     0.001466
# 3   11.wav     1085.892790    0.034433      1020.672022     0.000801
# 4   12.wav     1196.872419    0.002535      1216.199767     0.000798
# ..     ...             ...         ...              ...          ...
# 95  95.wav     1081.195988    0.000767      1185.071241     0.001826
# 96  96.wav     1662.705529    0.002969       944.212376     0.000305
# 97  97.wav     1082.968112    0.000668      2333.897373     0.013041
# 98  98.wav     1199.985127    0.002066      2805.501109     0.017828
# 99  99.wav     1266.605827    0.001102      1379.400758     0.001313
#
#     Lib Wiener Centroid  Lib Wiener Mean  Noised Centroid  Noised Mean
# 0           1441.370073         0.003337      1434.648537     0.002755
# 1           1991.513464         0.006635      1987.723863     0.006468
# 2           3116.519840         0.022828      3112.285498     0.022588
# 3           2641.395499         0.016842      2636.206145     0.016726
# 4           2247.903688         0.008474      2244.408269     0.008417
# ..                  ...              ...              ...          ...
# 95          1801.275891         0.007548      1799.917899     0.007528
# 96          1478.589749         0.002204      1478.112927     0.002189
# 97          3072.075131         0.030570      3075.659040     0.030633
# 98          3313.204914         0.031993      3315.393350     0.032134
# 99          1945.666247         0.006308      1947.297953     0.006325
#
# [100 rows x 9 columns]

# %%
df_absolute.describe()
# Out:
#        Clear Centroid  Clear Mean  Wiener Centroid  Wiener Mean  \
# count      100.000000  100.000000       100.000000   100.000000
# mean      1239.438801    0.034578      1288.961034     0.005489
# std        887.246756    0.067976       726.945764     0.010524
# min        360.508445    0.000006       368.998055     0.000028
# 25%        663.234579    0.000325       689.446115     0.000163
# 50%       1024.692255    0.000986      1061.474643     0.000748
# 75%       1468.177821    0.019389      1827.576407     0.006779
# max       5970.526134    0.345792      3166.537761     0.066741
#
#        Lib Wiener Centroid  Lib Wiener Mean  Noised Centroid  Noised Mean
# count           100.000000       100.000000       100.000000   100.000000
# mean           1976.670393         0.014214      1974.917713     0.014154
# std             737.544507         0.018103       738.046818     0.018121
# min             774.232597         0.000296       771.533678     0.000288
# 25%            1424.506087         0.002449      1422.302720     0.002438
# 50%            1795.345530         0.006548      1791.817289     0.006452
# 75%            2540.469485         0.020724      2539.030718     0.020672
# max            3948.914844         0.095383      3947.763228     0.095326

# %%
plt.figure(figsize=(10, 6))
for column in ["Clear Centroid", "Wiener Centroid", "Lib Wiener Centroid", "Noised Centroid"]:
    plt.plot(df_absolute["File"], df_absolute[column], marker="o", label=column)
plt.xlabel("Файл")
plt.ylabel("Значення")
plt.title("Абсолютні значення спектральних центроїд")
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))
for column in ["Clear Mean", "Wiener Mean", "Lib Wiener Mean", "Noised Mean"]:
    plt.plot(df_absolute["File"], df_absolute[column], marker="o", label=column)
plt.xlabel("Файл")
plt.ylabel("Значення")
plt.title("Абсолютні значення середніх спектральних площинностей")
plt.legend()
plt.show()
